# %%
import pandas as pd
import numpy as np

data = pd.read_csv('chem_oli_content_with_questions.csv')
display(data.head())
# Out:
#                                       Unit        Module  \
# 0  Composition of Substances and Solutions  Introduction
# 1  Composition of Substances and Solutions  Introduction
# 2  Composition of Substances and Solutions  Introduction
# 3  Chemical Bonding and Molecular Geometry  Introduction
# 4  Chemical Bonding and Molecular Geometry  Introduction
#
#                                                Title Subheaders  \
# 0  Introduction to Composition of Substances and ...        NaN
# 1  Introduction to Composition of Substances and ...        NaN
# 2  Introduction to Composition of Substances and ...        NaN
# 3  Introduction to Chemical Bonding and Molecular...        NaN
# 4  Introduction to Chemical Bonding and Molecular...        NaN
#
#                                         Cleaned Text  \
# 0  swimming pools have long been a popular means ...
# 1  swimming pools have long been a popular means ...
# 2  swimming pools have long been a popular means ...
# ...

# %%
data = data[data['Generated Question'].str.contains('when', case=False, na=False)]
display(data)
# Out:
#                                          Unit                  Module  \
# 3     Chemical Bonding and Molecular Geometry            Introduction
# 40                            Thermochemistry           Introduction
# 50                   Foundations of Chemistry  Elements and Compounds
# 55                   Foundations of Chemistry  Elements and Compounds
# 58                   Foundations of Chemistry  Elements and Compounds
# ...                                       ...                     ...
# 5275                       Solids and Liquids   Intermolecular Forces
# 5280                                Solutions              Solubility
# 5298                                    Gases                Gas Laws
# 5358                 Foundations of Chemistry  Elements and Compounds
# 5394                 Foundations of Chemistry            Measurements
#
#                                                   Title Subheaders  \
# ...
